# %%
# %pip install kagglehub
# Out:
# Requirement already satisfied: kagglehub in ./.venv/lib/python3.11/site-packages (1.0.2)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in ./.venv/lib/python3.11/site-packages (from kagglehub) (0.1.37)
# Requirement already satisfied: packaging in ./.venv/lib/python3.11/site-packages (from kagglehub) (26.3)
# Requirement already satisfied: pyyaml in ./.venv/lib/python3.11/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in ./.venv/lib/python3.11/site-packages (from kagglehub) (2.34.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.11/site-packages (from kagglehub) (4.70.0)
# Requirement already satisfied: protobuf in ./.venv/lib/python3.11/site-packages (from kagglesdk<1.0,>=0.1.22->kagglehub) (7.36.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.11/site-packages (from requests->kagglehub) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.11/site-packages (from requests->kagglehub) (3.19)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.11/site-packages (from requests->kagglehub) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.11/site-packages (from requests->kagglehub) (2026.7.22)
#
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("awsaf49/coco-2017-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/incor/.cache/kagglehub/datasets/awsaf49/coco-2017-dataset/versions/2
